# %%
from ultralytics import YOLO

# %%
model = YOLO(r"D:\Projects\Repos\ultralytics\yolov8n.pt")

# %%
trained_model = model.train(data=r"D:\Assignments\Achira_Labs\Code\custom.yaml", epochs=100, patience=10, save_period=5)
# Out:
# New https://pypi.org/project/ultralytics/8.0.158 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.7.16 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
model2 = YOLO(r"D:\Assignments\Achira_Labs\Code\runs\detect\train\weights\best.pt")

# %%
results = model2.predict(r"D:\Assignments\Achira_Labs\Model_Training\test\images", save=True, save_conf=True)
# Out:
# image 1/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_900.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 16.2ms
# image 2/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_901.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 11.2ms
# image 3/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_902.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 18.3ms
# image 4/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_903.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 14.0ms
# image 5/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_904.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 3.7ms
# image 6/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_905.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 10.5ms
# image 7/100 D:\Assignments\Achira_Labs\Model_Training\test\images\image_906.png: 640x640 10 discs, 10 gears, 10 hexagons, 10 squares, 10.2ms
# ...
